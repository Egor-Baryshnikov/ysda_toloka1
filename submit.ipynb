# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import os
import pandas as pd
# %matplotlib inline

# %%
from src.model import ImageClassifier
from src.utils import ImagesDataset, evaluate_model
from src.transforms import transform

# %%
model = ImageClassifier.load_from_checkpoint('model.ckpt')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-58d65b74cf84> in <module>
# ----> 1 model = ImageClassifier.load_from_checkpoint('model.ckpt')
#
# ~/.pyenv/versions/3.8.5/envs/sandbox/lib/python3.8/site-packages/pytorch_lightning/core/saving.py in load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#     155         checkpoint[cls.CHECKPOINT_HYPER_PARAMS_KEY].update(kwargs)
#     156
# --> 157         model = cls._load_model_state(checkpoint, strict=strict, **kwargs)
#     158         return model
#     159
#
# ~/.pyenv/versions/3.8.5/envs/sandbox/lib/python3.8/site-packages/pytorch_lightning/core/saving.py in _load_model_state(cls, checkpoint, strict, **cls_kwargs_new)
#     203
#     204         # load the state_dict on the model automatically
# --> 205         model.load_state_dict(checkpoint['state_dict'], strict=strict)
#     206
#     207         return model
#
# ~/.pyenv/versions/3.8.5/envs/sandbox/lib/python3.8/site-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#    1221
#    1222         if len(error_msgs) > 0:
# -> 1223             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1224                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    1225         return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for ImageClassifier:
# 	Missing key(s) in state_dict: "trunk.conv_stem.weight", "trunk.bn1.weight", "trunk.bn1.bias", "trunk.bn1.running_mean", "trunk.bn1.running_var", "trunk.blocks.0.0.conv_dw.weight", "trunk.blocks.0.0.bn1.weight", "trunk.blocks.0.0.bn1.bias", "trunk.blocks.0.0.bn1.running_mean", "trunk.blocks.0.0.bn1.running_var", "trunk.blocks.0.0.conv_pw.weight", "trunk.blocks.0.0.bn2.weight", "trunk.blocks.0.0.bn2.bias", "trunk.blocks.0.0.bn2.running_mean", "trunk.blocks.0.0.bn2.running_var", "trunk.blocks.1.0.conv_pw.weight", "trunk.blocks.1.0.bn1.weight", "trunk.blocks.1.0.bn1.bias", "trunk.blocks.1.0.bn1.running_mean", "trunk.blocks.1.0.bn1.running_var", "trunk.blocks.1.0.conv_dw.weight", "trunk.blocks.1.0.bn2.weight", "trunk.blocks.1.0.bn2.bias", "trunk.blocks.1.0.bn2.running_mean", "trunk.blocks.1.0.bn2.running_var", "trunk.blocks.1.0.conv_pwl.weight", "trunk.blocks.1.0.bn3.weight", "trunk.blocks.1.0.bn3.bias", "trunk.blocks.1.0.bn3.running_mean", "trunk.blocks.1.0.bn3.running_var", "trunk.blocks.1.1.conv_pw.weight", "trunk.blocks.1.1.bn1.weight", "trunk.blocks.1.1.bn1.bias", "trunk.blocks.1.1.bn1.running_mean", "trunk.blocks.1.1.bn
k.blocks.3.0.bn2.weight", "trunk.blocks.3.0.bn2.bias", "trunk.blocks.3.0.bn2.running_mean", "trunk.blocks.3.0.bn2.running_var", "trunk.blocks.3.0.conv_pwl.weight", "trunk.blocks.3.0.bn3.weight", "trunk.blocks.3.0.bn3.bias", "trunk.blocks.3.0.bn3.running_mean", "trunk.blocks.3.0.bn3.running_var", "trunk.blocks.3.1.conv_pw.weight", "trunk.blocks.3.1.bn1.weight", "trunk.blocks.3.1.bn1.bias", "trunk.blocks.3.1.bn1.running_mean", "trunk.blocks.3.1.bn1.running_var", "trunk.blocks.3.1.conv_dw.weight", "trunk.blocks.3.1.bn2.weight", "trunk.blocks.3.1.bn2.bias", "trunk.blocks.3.1.bn2.running_mean", "trunk.blocks.3.1.bn2.running_var", "trunk.blocks.3.1.conv_pwl.weight", "trunk.blocks.3.1.bn3.weight", "trunk.blocks.3.1.bn3.bias", "trunk.blocks.3.1.bn3.running_mean", "trunk.blocks.3.1.b ...
# 	Unexpected key(s) in state_dict: "trunk.trunk.trunk.trunk.trunk.trunk.conv_stem.weight", "trunk.trunk.trunk.trunk.trunk.trunk.bn1.weight", "trunk.trunk.trunk.trunk.trunk.trunk.bn1.bias", "trunk.trunk.trunk.trunk.trunk.trunk.bn1.running_mean", "trunk.trunk.trunk.trunk.trunk.trunk.bn1.running_var", "trunk.trunk.trunk.trunk.trunk.trunk.bn1.num_batches_tracked", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.0.0.conv_dw.weight", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.0.0.bn1.weight", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.0.0.bn1.bias", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.0.0.bn1.running_mean", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.0.0.bn1.running_var", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.0.0.bn1.num_batches_tracked", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.0.0.conv_pw.weight", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.0.0.bn2.weight", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.0.0.bn2.bias", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.0.0.bn2.running_mean", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.0.0.bn2.running_var", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.0.0.bn2.num_batches_tracked", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.0.conv_pw.weight", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.0.bn1.weight", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.0.bn1.bias", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.0.bn1.running_mean", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.0.bn1.running_var", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.0.bn1.num_batches_tracked", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.0.conv_dw.weight", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.0.bn2.weight", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.0.bn2.bias", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.0.bn2.running_mean", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.0.bn2.running_var", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.0.bn2.num_batches_tracked", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.0.conv_pwl.weight", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.0.bn3.weight", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.0.bn3.bias", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.0.bn3.running_mean", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.0.bn3.running_var", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.0.bn3.num_batches_tracked", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.1.conv_pw.weight", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.1.bn1.weight", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.1.bn1.bias", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.1.bn1.running_mean", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.1.bn1.running_var", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.1.bn1.num_batches_tracked", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.1.conv_dw.weight", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.1.bn2.weight", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.1.bn2.bias", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.1.bn2.running_mean", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.1.bn2.running_var", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.1.bn2.num_batches_tracked", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.1.conv_pwl.weight", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.1.bn3.weight", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.1.bn3.bias", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.1.bn3.running_mean", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.1.bn3.running_var", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.1.1.bn3.num_batches_tracked", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.2.0.conv_pw.weight", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.2.0.bn1.weight", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.2.0.bn1.bias", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.2.0.bn1.running_mean", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.2.0.bn1.running_var", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.2.0.bn1.num_batches_tracked", "trunk.trunk.trunk.trunk.trunk.trunk.blocks.2.0.conv_dw.weight", "trunk.trunk.trunk.trunk.trunk.trunk.blocks ...

# %%
test_images_paths = [os.path.join('dataset_students/classification/val', fname) for fname in os.listdir('dataset_students/classification/val')]
test_images_dataset = ImagesDataset(test_images_paths, transform=transform)

# %%
_, predictions = evaluate_model(model, test_images_dataset, batch_size=1)
# Out:
# 100%|██████████| 1/1 [00:08<00:00,  8.79s/it]

# %%
# Only the image name will be used when evaluating, the rest of the path does not matter
submission_df = pd.DataFrame({'img_path': test_images_paths, 'label': predictions})
submission_df.to_csv('submission.csv', index=False)
