# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import pandas as pd
import ipyplot
import torch
import pytorch_lightning as pl
from sklearn.metrics import f1_score
# %matplotlib inline

# %%
from src.model import ImageClassifier
from src.utils import ImagesDataset, evaluate_model
from src.transforms import transform
from src import params

# %% [markdown]
# # Load dataset

# %%
labelled_df = pd.read_csv('dataset/classification/aggregated_results_by_ds__pool_28797724__2021_10_19.tsv', sep='\t')
labelled_df = labelled_df.drop('Unnamed: 3', axis=1)
labelled_df['INPUT:images'] = labelled_df['INPUT:images'].apply(lambda x: 'dataset' + x[13:])
labelled_df['OUTPUT:result'] = (labelled_df['OUTPUT:result'] == 'ok').astype(int)
labelled_df['CONFIDENCE:result'] = labelled_df['CONFIDENCE:result'].apply(lambda x: float(x[:-1])/100)

# %%
labelled_df = labelled_df[labelled_df['CONFIDENCE:result'] > 0.95]
print("# Confident labels: ", len(labelled_df))
labelled_df = labelled_df.drop('CONFIDENCE:result', axis=1)
labelled_df.columns = ['img_path', 'label']
labelled_df.head()
# Out:
# # Confident labels:  8452
#                                            img_path  label
# 0  dataset/classification/train_unlabelled/6551.png      0
# 1  dataset/classification/train_unlabelled/2723.png      1
# 2  dataset/classification/train_unlabelled/3777.png      0
# 3  dataset/classification/train_unlabelled/2858.png      1
# 4   dataset/classification/train_unlabelled/543.png      1

# %%
train_df = pd.read_csv('dataset/classification/train_labelled.csv')
train_df.head()
# Out:
#                                       img_path  label
# 0  dataset/classification/train_labelled/0.png      0
# 1  dataset/classification/train_labelled/1.png      0
# 2  dataset/classification/train_labelled/2.png      0
# 3  dataset/classification/train_labelled/3.png      0
# 4  dataset/classification/train_labelled/4.png      0

# %%
train_df = train_df.append(labelled_df, ignore_index=True)

# %%
train_image_paths = train_df.img_path.values
train_labels = train_df.label.values

# %%
len(train_image_paths)
# Out:
# 9452

# %%
ipyplot.plot_class_tabs(train_image_paths, train_labels)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-HrDgekRmsxkX6JF5nbhjMk {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-HrDgekRmsxkX6JF5nbhjMk {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-HrDgekRmsxkX6JF5nbhjMk {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-HrDgekRmsxkX6JF5nbhjMk:checked ~ #ipyplot-html-viewer-textarea-HrDgekRmsxkX6JF5nbhjMk {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-HrDgekRmsxkX6JF5nbhjMk:checked + #ipyplot-html-viewer-label-HrDgekRmsxkX6JF5nbhjMk:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-HrDgekRmsxkX6JF5nbhjMk">
#         <label id="ipyplot-html-viewer-label-HrDgekRmsxkX6JF5nbhjMk" for="ipyplot-html-viewer-toggle-HrDgekRmsxkX6JF5nbhjMk">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-HrDgekRmsxkX6JF5nbhjMk" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-dkKcBoftNNJAe6N2CJ4Wo3 {
#                 display: none;
#             }
#             input.ipyplot-tab-dkKcBoftNNJAe6N2CJ4Wo3 + label.ipyplot-tab-label-dkKcBoftNNJAe6N2CJ4Wo3 {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-dkKcBoftNNJAe6N2CJ4Wo3:checked + label.ipyplot-tab-label-dkKcBoftNNJAe6N2CJ4Wo3 {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-dkKcBoftNNJAe6N2CJ4Wo3 ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-dkKcBoftNNJAe6N2CJ4Wo3 ~ .tab {
#                 display: none
#             }
#     #tab66UfmWniJ88tjAwAERW6rv:checked ~ .tab.content66UfmWniJ88tjAwAERW6rv,#tabmdaBUFcdrLDcaWoigszBY3:checked ~ .tab.contentmdaBUFcdrLDcaWoigszBY3{ display: block; }</style><input class="ipyplot-tab-dkKcBoftNNJAe6N2CJ4Wo3" type="radio" name="tabs-dkKcBoftNNJAe6N2CJ4Wo3" id="tab66UfmWniJ88tjAwAERW6rv" checked /><label class="ipyplot-tab-label-dkKcBoftNNJAe6N2CJ4Wo3" for="tab66UfmWniJ88tjAwAERW6rv">0</label><input class="ipyplot-tab-dkKcBoftNNJAe6N2CJ4Wo3" type="radio" name="tabs-dkKcBoftNNJAe6N2CJ4Wo3" id="tabmdaBUFcdrLDcaWoigszBY3"/><label class="ipyplot-tab-label-dkKcBoftNNJAe6N2CJ4Wo3" for="tabmdaBUFcdrLDcaWoigszBY3">1</label><div class="tab content66UfmWniJ88tjAwAERW6rv">
#         <style>
#         #ipyplot-imgs-container-div-eKn4p6aGrPD7CDyuh2AUya {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-eKn4p6aGrPD7CDyuh2AUya {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-eKn4p6aGrPD7CDyuh2AUya">
#     <div class="ipyplot-placeholder-div-eKn4p6aGrPD7CDyuh2AUya">
#         <div id="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya-b2hCHjfgxh7bmj74LdUTFC" class="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">dataset/classification/train_labelled/0.png</h4><img src="dataset/classification/train_labelled/0.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya-b2hCHjfgxh7bmj74LdUTFC">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eKn4p6aGrPD7CDyuh2AUya">
#         <div id="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya-DtRXLJdwxZ5MLb8oubxEpn" class="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">dataset/classification/train_labelled/1.png</h4><img src="dataset/classification/train_labelled/1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya-DtRXLJdwxZ5MLb8oubxEpn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eKn4p6aGrPD7CDyuh2AUya">
#         <div id="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya-9XX3J9RNUUrXFzi2ePp78m" class="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">dataset/classification/train_labelled/2.png</h4><img src="dataset/classification/train_labelled/2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya-9XX3J9RNUUrXFzi2ePp78m">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eKn4p6aGrPD7CDyuh2AUya">
#         <div id="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya-2M9LePV6Nef3YP3ksvNWaf" class="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-w
# <div>
#         <style>
#             input.ipyplot-tab-dkKcBoftNNJAe6N2CJ4Wo3 {
#                 display: none;
#             }
#             input.ipyplot-tab-dkKcBoftNNJAe6N2CJ4Wo3 + label.ipyplot-tab-label-dkKcBoftNNJAe6N2CJ4Wo3 {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-dkKcBoftNNJAe6N2CJ4Wo3:checked + label.ipyplot-tab-label-dkKcBoftNNJAe6N2CJ4Wo3 {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-dkKcBoftNNJAe6N2CJ4Wo3 ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-dkKcBoftNNJAe6N2CJ4Wo3 ~ .tab {
#                 display: none
#             }
#     #tab66UfmWniJ88tjAwAERW6rv:checked ~ .tab.content66UfmWniJ88tjAwAERW6rv,#tabmdaBUFcdrLDcaWoigszBY3:checked ~ .tab.contentmdaBUFcdrLDcaWoigszBY3{ display: block; }</style><input class="ipyplot-tab-dkKcBoftNNJAe6N2CJ4Wo3" type="radio" name="tabs-dkKcBoftNNJAe6N2CJ4Wo3" id="tab66UfmWniJ88tjAwAERW6rv" checked /><label class="ipyplot-tab-label-dkKcBoftNNJAe6N2CJ4Wo3" for="tab66UfmWniJ88tjAwAERW6rv">0</label><input class="ipyplot-tab-dkKcBoftNNJAe6N2CJ4Wo3" type="radio" name="tabs-dkKcBoftNNJAe6N2CJ4Wo3" id="tabmdaBUFcdrLDcaWoigszBY3"/><label class="ipyplot-tab-label-dkKcBoftNNJAe6N2CJ4Wo3" for="tabmdaBUFcdrLDcaWoigszBY3">1</label><div class="tab content66UfmWniJ88tjAwAERW6rv">
#         <style>
#         #ipyplot-imgs-container-div-eKn4p6aGrPD7CDyuh2AUya {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-eKn4p6aGrPD7CDyuh2AUya {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-eKn4p6aGrPD7CDyuh2AUya">
#     <div class="ipyplot-placeholder-div-eKn4p6aGrPD7CDyuh2AUya">
#         <div id="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya-b2hCHjfgxh7bmj74LdUTFC" class="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">dataset/classification/train_labelled/0.png</h4><img src="dataset/classification/train_labelled/0.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya-b2hCHjfgxh7bmj74LdUTFC">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eKn4p6aGrPD7CDyuh2AUya">
#         <div id="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya-DtRXLJdwxZ5MLb8oubxEpn" class="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">dataset/classification/train_labelled/1.png</h4><img src="dataset/classification/train_labelled/1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya-DtRXLJdwxZ5MLb8oubxEpn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eKn4p6aGrPD7CDyuh2AUya">
#         <div id="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya-9XX3J9RNUUrXFzi2ePp78m" class="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">dataset/classification/train_labelled/2.png</h4><img src="dataset/classification/train_labelled/2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya-9XX3J9RNUUrXFzi2ePp78m">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eKn4p6aGrPD7CDyuh2AUya">
#         <div id="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya-2M9LePV6Nef3YP3ksvNWaf" class="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">dataset/classification/train_labelled/3.png</h4><img src="dataset/classification/train_labelled/3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya-2M9LePV6Nef3YP3ksvNWaf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eKn4p6aGrPD7CDyuh2AUya">
#         <div id="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya-6eHRwzhmcFF8p83QPDRxhA" class="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">dataset/classification/train_labelled/4.png</h4><img src="dataset/classification/train_labelled/4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya-6eHRwzhmcFF8p83QPDRxhA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eKn4p6aGrPD7CDyuh2AUya">
#         <div id="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya-AYipkhERiVoCoerjJvdAzm" class="ipyplot-content-div-eKn4p6aGrPD7CDyuh2AUya">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; w

# %% [markdown]
# # Split dataset

# %%
total_len = len(train_image_paths)
n_train = int(0.7 * total_len)
n_valid = int(0.2 * total_len)
n_test = total_len - n_train - n_valid

# %%
import numpy as np
np.random.seed(420)

# %%
rand_idcs = np.random.permutation(train_df.index)
train_idcs = rand_idcs[:n_train]
val_idcs = rand_idcs[n_train:n_train+n_valid]
test_idcs = rand_idcs[n_train+n_valid:n_train+n_valid+n_test]

# %%
train_X, train_y = train_df.loc[train_idcs,'img_path'], train_df.loc[train_idcs, 'label']
val_X, val_y = train_df.loc[val_idcs,'img_path'], train_df.loc[val_idcs, 'label']
test_X, test_y = train_df.loc[test_idcs,'img_path'], train_df.loc[test_idcs, 'label']

# %% [markdown]
# # Prepare model

# %%
train_dataset = ImagesDataset(list(train_X), list(train_y), transform=transform)
val_dataset = ImagesDataset(list(val_X), list(val_y), transform=transform)
test_dataset = ImagesDataset(list(test_X), list(test_y), transform=transform)

# %%
from matplotlib import pyplot as plt

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, 
                                           batch_size=params.BATCH_SIZE,
                                           num_workers=16,
                                           shuffle=True)
val_loader = torch.utils.data.DataLoader(train_dataset, 
                                           batch_size=params.BATCH_SIZE,
                                           num_workers=16,
                                           shuffle=False)

# %%
weights = torch.Tensor([10,1])#torch.Tensor(np.bincount(train_y).tolist())

# %%
# Run macos_cert_fix.py if you are getting ssl errors
model = ImageClassifier(class_weight=weights, learning_rate=params.LEARNING_RATE)

# %%
model = ImageClassifier(trunk=model, class_weight=weights, learning_rate=1e-4)

# %%
trainer = pl.Trainer(
    max_epochs=5, #params.MAX_EPOCHS,
    log_every_n_steps=1, # Change to enable tensorboard logging
#     accelerator="dp",
    gpus=[1] # Uncomment to use GPU training
)
trainer.fit(model, train_loader, val_loader)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2]
#
#   | Name      | Type             | Params
# -----------------------------------------------
# 0 | trunk     | ImageClassifier  | 2.2 M
# 1 | loss      | CrossEntropyLoss | 0
# 2 | train_acc | Accuracy         | 0
# 3 | valid_acc | Accuracy         | 0
# -----------------------------------------------
# 2.2 M     Trainable params
# 0         Non-trainable params
# 2.2 M     Total params
# 8.906     Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]

# %% [markdown]
# # Compute training set accuracy

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
labels, predictions = evaluate_model(model, test_dataset, num_workers=20, device='cuda:0')
# Out:
#   0%|          | 0/30 [00:01<?, ?it/s]

# %%
f1_score(labels, predictions, labels=1, average='binary')
# Out:
# 0.922077922077922

# %%
accuracy_score(labels, predictions)
# Out:
# 0.9873015873015873

# %%
print(classification_report(labels, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1730
#            1       0.96      0.89      0.92       160
#
#     accuracy                           0.99      1890
#    macro avg       0.97      0.94      0.96      1890
# weighted avg       0.99      0.99      0.99      1890

# %%
from torchvision import transforms
test_transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Resize((50, 200)), # Hint: this might not be the best way to resize images
     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]) # Hint: this might not be the best normalization
     ]
)
test_dataset = ImagesDataset(list(test_X), list(test_y), transform=test_transform)

# %%
labels, predictions = evaluate_model(model, test_dataset, num_workers=20, device='cuda:0')
# Out:
#   0%|          | 0/30 [00:01<?, ?it/s]

# %%
f1_score(labels, predictions, labels=1, average='binary')
# Out:
# 0.9689440993788819

# %%
accuracy_score(labels, predictions)
# Out:
# 0.9947145877378436

# %%
print(classification_report(labels, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       863
#            1       1.00      0.94      0.97        83
#
#     accuracy                           0.99       946
#    macro avg       1.00      0.97      0.98       946
# weighted avg       0.99      0.99      0.99       946

# %% [markdown]
# # Save model

# %%
trainer.save_checkpoint("model.ckpt")

# %% [markdown]
# # Inference

# %%
from pathlib import Path
inf_imgs = list(Path("dataset/classification/test/").glob("*.png"))
inf_dataset = ImagesDataset(inf_imgs, transform=test_transform)

# %%
_, predictions = evaluate_model(model, inf_dataset, batch_size=32, num_workers=20, device='cuda:0')
# Out:
#   0%|          | 0/184 [00:01<?, ?it/s]

# %%
# Only the image name will be used when evaluating, the rest of the path does not matter
submission_df = pd.DataFrame({'img_path': inf_imgs, 'label': predictions})

# %%
submission_df['img_path'] = submission_df['img_path'].apply(lambda x: x.name)

# %%
submission_df.to_csv('submission.csv', index=False)

# %%
# !git clone
